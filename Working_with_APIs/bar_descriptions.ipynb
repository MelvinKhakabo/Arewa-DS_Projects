# %% [markdown]
# ## Adding Custom Tooltips

# %% [markdown]
# In Pygal, hovering the cursor over an individual bar shows the information that the bar represents. This is commonly called a tooltip, and in this case it currently shows the number of stars a project has. Let’s create a custom
# tooltip to show each project’s description as well.

# %%
import matplotlib.pyplot as plt

# Data for the chart
x_labels = ['public-apis', 'system-design-primer', 'awesome-python']
values = [325420, 286737, 231345]
descriptions = [
    'public-apis starred projects',
    'system-design-primer starred projects',
    'awesome-python starred projects',
]
links = [
    'https://github.com/public-apis',
    'https://github.com/system-design-primer',
    'https://github.com/awesome-python',
]

# Create a bar chart
plt.figure(figsize=(10, 6))  # Set figure size
bars = plt.bar(x_labels, values, color='#333366', edgecolor='black')

# Add titles and labels
plt.title('Most Starred Python Projects', fontsize=16)
plt.xlabel('Repositories', fontsize=14)
plt.ylabel('Stars', fontsize=14)

# Annotate the bars with descriptions and values
for bar, value, desc in zip(bars, values, descriptions):
    # Add the value above the bar
    plt.text(
        bar.get_x() + bar.get_width() / 2, 
        bar.get_height() + 5000,  # Offset slightly above the bar
        f'{value:,}',  # Format value with commas
        ha='center', 
        va='bottom', 
        fontsize=10, 
        color='black'
    )
    # Add the description below the bar (angled for better readability)
    plt.text(
        bar.get_x() + bar.get_width() / 2, 
        bar.get_height() / 2,  # Position at the middle of the bar
        desc, 
        ha='center', 
        va='center', 
        fontsize=9, 
        color='white', 
        rotation=90, 
        bbox=dict(facecolor='#444477', alpha=0.7)  # Add a semi-transparent background
    )

# Adjust layout for better appearance
plt.tight_layout()

# Display the chart
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# _Each bar has a customized tooltip label._
