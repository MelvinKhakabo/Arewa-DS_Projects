# %% [markdown]
# ## Adding Custom Tooltips

# %% [markdown]
# In Pygal, hovering the cursor over an individual bar shows the information that the bar represents. This is commonly called a tooltip, and in this case it currently shows the number of stars a project has. Let’s create a custom
# tooltip to show each project’s description as well.

# %%
import matplotlib.pyplot as plt

# Data for the chart
x_labels = ['public-apis', 'system-design-primer', 'awesome-python']
values = [325420, 286737, 231345]
descriptions = [
    'public-apis starred projects',
    'system-design-primer starred projects',
    'awesome-python starred projects',
]

# Use an available Matplotlib style
plt.style.use('seaborn-v0_8-darkgrid')  # Updated to a valid style from your list

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Create the bar chart
bars = ax.bar(x_labels, values, color='#333366', edgecolor='black')

# Add title and labels
ax.set_title('Most Starred Python Projects', fontsize=16)
ax.set_xlabel('Repositories', fontsize=12)
ax.set_ylabel('Stars', fontsize=12)

# Add descriptions as annotations
for bar, description in zip(bars, descriptions):
    height = bar.get_height()
    ax.text(
        bar.get_x() + bar.get_width() / 2,  # Center of the bar
        height + 5000,  # Slightly above the bar
        description,
        ha='center', va='bottom', fontsize=10, color='black', wrap=True
    )

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)

# Optimize layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# _Each bar has a customized tooltip label._
